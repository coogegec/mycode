# %%
import pandas as pd

df=pd.read_csv('d:/data/time/data2.csv')
df.head()
# Out:
#          date     price
# 0  1991-01-01  12588862
# 1  1991-02-01  12154321
# 2  1991-03-01  14337072
# 3  1991-04-01  15108570
# 4  1991-05-01  17225734

# %%
# 전처리
from pandas.tseries.offsets import MonthEnd
# 문자열 변수 date를 datetime 타입으로 바꾸고 MonthEnd(1)을 더하여 해당 월의 마지막 날짜로 지정
df['date']=pd.to_datetime(df['date'])+MonthEnd(1)
# 이 날짜를 index로 설정
df=df.set_index('date')
print(df.head())
df.plot()
# 인덱스가 0,1,2,3...에서 날짜로 변경됨
# 학습할 변수는 date
# Out:
#                price
# date
# 1991-01-31  12588862
# 1991-02-28  12154321
# 1991-03-31  14337072
# 1991-04-30  15108570
# 1991-05-31  17225734
# <AxesSubplot:xlabel='date'>

# %%
import matplotlib.pyplot as plt
split_date=pd.Timestamp('01-01-2011')
train=df.loc[:split_date, ['price']] # 학습용 : 2011/01/01까지의 자료
test=df.loc[split_date:, ['price']] # 검증용 : 이후 자료
ax=train.plot()
test.plot(ax=ax)
plt.legend(['train', 'test'])

# %%
# 스케일링
from sklearn.preprocessing import MinMaxScaler

sc=MinMaxScaler()
sc.fit(train)
train_sc=sc.transform(train)
test_sc=sc.transform(test)

train_sc[:10]
# Out:
# array([[0.01402033],
#        [0.        ],
#        [0.0704258 ],
#        [0.09531795],
#        [0.16362761],
#        [0.13514108],
#        [0.12395846],
#        [0.12617398],
#        [0.09230917],
#        [0.11139526]])

# %%
# 넘파이 배열을 데이터프레임으로 변환
train_sc_df=pd.DataFrame(train_sc, columns=['Scaled'], index=train.index)
test_sc_df=pd.DataFrame(test_sc, columns=['Scaled'], index=test.index)
train_sc_df.head()
# Out:
#               Scaled
# date
# 1991-01-31  0.014020
# 1991-02-28  0.000000
# 1991-03-31  0.070426
# 1991-04-30  0.095318
# 1991-05-31  0.163628

# %%
s=pd.Series([100,200,300])
s2=s.shift(1) # 아래로 한 칸 내려줌
print(s)
print(s2)
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64
# 0      NaN
# 1    100.0
# 2    200.0
# dtype: float64

# %%
for s in range(1,13):
    train_sc_df[f'shift_{s}']=train_sc_df['Scaled'].shift(s)
    test_sc_df[f'shift_{s}']=test_sc_df['Scaled'].shift(s)

train_sc_df.head(13)
# Out:
#               Scaled   shift_1   shift_2   shift_3   shift_4   shift_5  \
# date
# 1991-01-31  0.014020       NaN       NaN       NaN       NaN       NaN
# 1991-02-28  0.000000  0.014020       NaN       NaN       NaN       NaN
# 1991-03-31  0.070426  0.000000  0.014020       NaN       NaN       NaN
# 1991-04-30  0.095318  0.070426  0.000000  0.014020       NaN       NaN
# 1991-05-31  0.163628  0.095318  0.070426  0.000000  0.014020       NaN
# 1991-06-30  0.135141  0.163628  0.095318  0.070426  0.000000  0.014020
# 1991-07-31  0.123958  0.135141  0.163628  0.095318  0.070426  0.000000
# 1991-08-31  0.126174  0.123958  0.135141  0.163628  0.095318  0.070426
# 1991-09-30  0.092309  0.126174  0.123958  0.135141  0.163628  0.095318
# 1991-10-31  0.111395  0.092309  0.126174  0.123958  0.135141  0.163628
# 1991-11-30  0.131738  0.111395  0.092309  0.126174  0.123958  0.135141
# 1991-12-31  0.200913  0.131738  0.111395  0.092309  0.126174  0.123958
# ...

# %%
# 결측값(NaN) 제거
# 독립변수 : shift_1 ~ shift_12
X_train=train_sc_df.dropna().drop('Scaled', axis=1)
# 종속변수 : Scaled
y_train=train_sc_df.dropna()[['Scaled']]

X_test=test_sc_df.dropna().drop('Scaled', axis=1)
y_test=test_sc_df.dropna()[['Scaled']]

# %%
# 넘파이 배열로 저장
X_train=X_train.values
X_test=X_test.values
y_train=y_train.values
y_test=y_test.values

print(X_train)
print(y_train)
# Out:
# [[0.20091289 0.13173822 0.11139526 ... 0.0704258  0.         0.01402033]
#  [0.03002688 0.20091289 0.13173822 ... 0.09531795 0.0704258  0.        ]
#  [0.01999285 0.03002688 0.20091289 ... 0.16362761 0.09531795 0.0704258 ]
#  ...
#  [0.79916654 0.81439355 0.86398323 ... 0.92972161 0.71629034 0.77368724]
#  [0.80210057 0.79916654 0.81439355 ... 0.59734863 0.92972161 0.71629034]
#  [0.81482896 0.80210057 0.79916654 ... 0.53166512 0.59734863 0.92972161]]
# [[0.03002688]
#  [0.01999285]
#  [0.06596369]
#  [0.10983126]
#  [0.14912986]
#  [0.14718865]
#  [0.14464787]
#  [0.11898427]
#  [0.11802682]
#  [0.14222108]
#  [0.12459168]
#  [0.24290801]
#  [0.04899091]
#  [0.02408276]
#  [0.09865054]
#  [0.14480155]
#  [0.17061844]
#  [0.17067229]
#  [0.17603636]
#  [0.1449117 ]
#  [0.14957943]
#  [0.15381982]
#  [0.16036484]
#  [0.28308682]
#  [0.05971347]
#  [0.05306762]
#  [0.15199345]
#  [0.17230214]
#  [0.21246911]
#  [0.23131079]
#  [0.1982186 ]
#  [0.19187716]
#  [0.19381714]
# ...

# %%
# 케라스에 필요한 3차원 형태로 변환
# RNN에는 시간 기념이 있기 때문에 차원이 추가됨
#[size, timestep, 변수 개수]
X_train_t=X_train.reshape(X_train.shape[0], 12, 1)
X_test_t=X_test.reshape(X_test.shape[0], 12, 1)
print('최종 DATA')
print(X_train_t.shape)
print(X_train_t)
print(y_train)
# Out:
# 최종 DATA
# (228, 12, 1)
# [[[0.20091289]
#   [0.13173822]
#   [0.11139526]
#   ...
#   [0.0704258 ]
#   [0.        ]
#   [0.01402033]]
#
#  [[0.03002688]
#   [0.20091289]
#   [0.13173822]
#   ...
#   [0.09531795]
#   [0.0704258 ]
#   [0.        ]]
#
#  [[0.01999285]
#   [0.03002688]
#   [0.20091289]
#   ...
#   [0.16362761]
#   [0.09531795]
#   [0.0704258 ]]
#
#  ...
#
#  [[0.79916654]
#   [0.81439355]
#   [0.86398323]
#   ...
#   [0.92972161]
#   [0.71629034]
#   [0.77368724]]
#
#  [[0.80210057]
#   [0.79916654]
#   [0.81439355]
#   ...
#   [0.59734863]
#   [0.92972161]
#   [0.71629034]]
#
#  [[0.81482896]
#   [0.80210057]
#   [0.79916654]
#   ...
#   [0.53166512]
#   [0.59734863]
#   [0.92972161]]]
# [[0.03002688]
#  [0.01999285]
#  [0.06596369]
#  [0.10983126]
#  [0.14912986]
#  [0.14718865]
#  [0.14464787]
#  [0.11898427]
#  [0.11802682]
#  [0.14222108]
#  [0.12459168]
#  [0.24290801]
#  [0.04899091]
#  [0.02408276]
#  [0.09865054]
#  [0.14480155]
#  [0.17061844]
#  [0.17067229]
# ...

# %%
from keras.layers import LSTM
from keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping

model=Sequential() # Sequential model
model.add(LSTM(20, input_shape=(12,1))) # (timestep, 변수 개수)
model.add(Dense(1)) # 출력층의 노드 개수 1
model.compile(loss='mse', optimizer='adam')

# %%
model.fit(X_train_t, y_train, epochs=250, batch_size=30, verbose=1)
# Out:
# Epoch 1/250
# 8/8 [==============================] - 11s 8ms/step - loss: 0.1425
# Epoch 2/250
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0717
# Epoch 3/250
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0209
# Epoch 4/250
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0140
# Epoch 5/250
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0127
# Epoch 6/250
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0096
# Epoch 7/250
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0096
# Epoch 8/250
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0087
# Epoch 9/250
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0084
# Epoch 10/250
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0079
# Epoch 11/250
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0078
# Epoch 12/250
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0075
# ...

# %%
score=model.evaluate(X_test_t, y_test, verbose=0)
print(score) # 평균제곱오차
y_pred=model.predict(X_test_t)
print(y_pred.flatten()[:10])
print(y_test.flatten()[:10])
# Out:
# 0.0015419009141623974
# [0.6527062  0.6016489  0.7914014  0.850479   0.9152522  0.94459474
#  0.9154949  0.9079632  0.88722384 0.8640989 ]
# [0.65198848 0.6431242  0.83176496 0.82666946 0.98182284 0.95616179
#  0.90265615 0.94107108 0.86841056 0.88189991]

# %%
import numpy as np

np.mean(y_test.flatten()-y_pred.flatten()) # (실제값) - (예측값) 의 평균
# Out:
# 0.022490195765037878

# %%
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(15,4))
plt.plot(y_test.flatten(), 'ro-', label='real values') # 실제값(빨강)
plt.plot(y_pred.flatten(), 'bo-', label='predict values') # 예측값(파랑)
plt.legend()
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 흑백 이미지 로드
image=cv2.imread("d:/data/images/1da2de2ba7.jpg", cv2.IMREAD_GRAYSCALE)

# %%
# 이미지를 출력
plt.imshow(image, cmap="gray")
plt.axis('off')
plt.show()

# %%
# 데이터 타입을 확인
type(image)
# Out:
# numpy.ndarray

# %%
# 이미지 데이터를 확인
image
# Out:
# array([[ 71,  75,  85, ..., 150, 137, 128],
#        [ 31,  34,  40, ..., 186, 177, 169],
#        [ 17,  18,  18, ..., 212, 206, 201],
#        ...,
#        [ 61,  60,  60, ...,  54,  60,  63],
#        [ 63,  62,  62, ...,  64,  63,  58],
#        [ 60,  59,  60, ...,  71,  74,  75]], dtype=uint8)

# %%
# 이미지의 해상도(차원)
image.shape
# Out:
# (200, 200)

# %%
# 컬러로 이미지를 로드
image_bgr=cv2.imread("d:/data/images/1da2de2ba7.jpg", cv2.IMREAD_COLOR)

image_bgr[0,0] # 픽셀을 확인
# opencv에서는 bgr color를 사용하므로 matplotlib에서 출력하려면 변환해야함

# %%
# BGR을 RGB로 변환
image_bgr=cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# 이미지를 출력
plt.imshow(image_bgr)
plt.axis('off')
plt.show()

# %%
# 이미지 저장
cv2.imwrite("d:/data/images/duckmeat_grayscale.jpg", image)
# Out:
# True

# %%
### 이미지 크기 변경
# 이미지 사이즈를 조절하는 이유
# 1. 다양한 사이즈의 이미지를 데이터 분석에 사용하려면 사이즈를 통일해야 함
# 2. 이미지 크기를 줄여서 메모리 사용량을 줄일 수 있음
# 흑백 이미지 로드
image=cv2.imread('d:/data/images/1fc4298637.jpg', cv2.IMREAD_GRAYSCALE) # 200×200 픽셀

# 이미지 크기를 50×50 픽셀로 변환
image_50x50=cv2.resize(image, (50,50))

# 이미지를 출력
plt.imshow(image_50x50, cmap='gray')
plt.xticks([])
plt.yticks([])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
### 이미지 자르기
# 흑백 이미지 로드
image=cv2.imread('d:/data/images/1fc4298637.jpg', cv2.IMREAD_GRAYSCALE) # 200×200 픽셀
# 열의 처음 절반과 모든 행을 선택
image_cropped=image[:,:100]
# 이미지를 출력
plt.imshow(image_cropped, cmap='gray')
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
### 이미지 흐리게 하기
# 이미지를 흐리게 하려면 각 픽셀을 주변 픽셀의 평균값으로 변환
# 흑백 이미지를 로드
image=cv2.imread('d:/data/images/1fc4298637.jpg', cv2.IMREAD_GRAYSCALE)

# 이미지를 흐리게
# 커널 사이즈 10×10, 커널 사이즈가 클수록 이미지가 더 부드러워지게 됨
image_blurry=cv2.blur(image,(8,8))

# 이미지를 출력
plt.imshow(image_blurry, cmap='gray')
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 커널을 만드는 방법
# 5×5 커널
kernel=np.ones((5,5))/25.0
# 커널의 값을 모두 더하면 1

# 커널을 확인
kernel
# Out:
# array([[0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04]])

# %%
# 커널을 적용
# src: 이미지
# ddepth: 이미지 깊이(자료형 크기). -1이면 입력과 동일
# kernel: 커널 행렬
image_kernel=cv2.filter2D(image, -1, kernel)

# 이미지를 출력
plt.imshow(image_kernel, cmap='gray')
plt.xticks([])
plt.yticks([])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
### 이미지를 선명하게 처리
# 흑백 이미지를 로드
image=cv2.imread('d:/data/images/1fc4298637.jpg', cv2.IMREAD_GRAYSCALE)

# 중앙 픽셀을 부각하는 커널
kernel=np.array([[0, -1, 0],[-1, 5, -1],[0, -1, 0]])

# 이미지를 선명하게 처리
image_sharp=cv2.filter2D(image, -1, kernel)

# 이미지를 출력
plt.imshow(image_sharp, cmap='gray')
plt.xticks([])
plt.yticks([])
plt.show
# 이미지의 경계선에서 대비가 강조되게 됨
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
### 대비 향상
# 흑백 이미지를 로드
image=cv2.imread('d:/data/images/1fc4298637.jpg', cv2.IMREAD_GRAYSCALE)

# 이미지 대비를 향상시킴
image_enhanced=cv2.equalizeHist(image)

# 이미지를 출력
plt.imshow(image_enhanced, cmap='gray')
plt.xticks([])
plt.yticks([])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
### 경계선 감지 : 경계선은 많은 정보가 담긴 영역
# 정보가 적은 영역을 제거하고 대부분의 정보가 담긴 이미지 영역을 구분할 수 있음
# 흑백 이미지를 로드
image=cv2.imread('d:/data/images/1fc4298637.jpg', cv2.IMREAD_GRAYSCALE)

# 픽셀 강도의 중간값을 계산
median_intensity=np.median(image)

# 중간 픽셀 강도에서 위아래 1 표준편차 떨어진 값을 임계값으로 지정
lower_threshold=int(max(0,(1.0-0.33)*median_intensity))
upper_threshold=int(min(255,(1.0+0.33)*median_intensity))

# 경계선 감지 함수를 적용
image_canny=cv2.Canny(image, lower_threshold, upper_threshold)

# 이미지를 출력
plt.imshow(image_canny, cmap='gray')
plt.xticks([])
plt.yticks([])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
